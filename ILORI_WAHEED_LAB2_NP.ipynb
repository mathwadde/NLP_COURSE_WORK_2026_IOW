# %%
import sys
# !{sys.executable} -m pip install spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: spacy in ./.local/lib/python3.9/site-packages (3.5.0)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy) (1.21.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./.local/lib/python3.9/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy) (2.27.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./.local/lib/python3.9/site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./.local/lib/python3.9/site-packages (from spacy) (3.0.13)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy) (21.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./.local/lib/python3.9/site-packages (from spacy) (2.5.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./.local/lib/python3.9/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./.local/lib/python3.9/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in ./.local/lib/python3.9/site-packages (from spacy) (8.1.12)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in ./.local/lib/python3.9/site-packages (from spacy) (0.7.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./.local/lib/python3.9/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./.local/lib/python3.9/site-packages (from spacy) (3.5.1)
# Requirement already satisfied: pathy>=0.10.0 in ./.local/lib/python3.9/site-packages (from spacy) (0.11.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in ./.local/lib/python3.9/site-packages (from spacy) (1.10.26)
# Requirement already satisfied: jinja2 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy) (2.11.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy) (4.64.0)
# Requirement already satisfied: setuptools in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy) (61.2.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./.local/lib/python3.9/site-packages (from spacy) (1.0.15)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in ./.local/lib/python3.9/site-packages (from spacy) (6.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from packaging>=20.0->spacy) (3.0.4)
# Requirement already satisfied: pathlib-abc==0.1.1 in ./.local/lib/python3.9/site-packages (from pathy>=0.10.0->spacy) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./.local/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./.local/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.1.5)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./.local/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.11)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from jinja2->spacy) (2.0.1)

# %%
import sys
# !{sys.executable} -m pip install spacy==3.5.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: spacy==3.5.0 in ./.local/lib/python3.9/site-packages (3.5.0)
# Requirement already satisfied: jinja2 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy==3.5.0) (2.11.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (6.4.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (1.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (2.0.10)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (1.0.15)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy==3.5.0) (1.21.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (3.0.12)
# Requirement already satisfied: pathy>=0.10.0 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (0.11.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (2.5.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy==3.5.0) (4.64.0)
# Requirement already satisfied: setuptools in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy==3.5.0) (61.2.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (0.7.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (3.5.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (2.0.13)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (1.1.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (1.10.26)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy==3.5.0) (21.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (3.0.13)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy==3.5.0) (2.27.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from packaging>=20.0->spacy==3.5.0) (3.0.4)
# Requirement already satisfied: pathlib-abc==0.1.1 in ./.local/lib/python3.9/site-packages (from pathy>=0.10.0->spacy==3.5.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./.local/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy==3.5.0) (4.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (1.26.9)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./.local/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy==3.5.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./.local/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy==3.5.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy==3.5.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from jinja2->spacy==3.5.0) (2.0.1)

# %%
# Install required libraries (uncomment if needed)
# !pip install nltk spacy
# !python -m spacy download en_core_web_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 23.4 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in ./.local/lib/python3.9/site-packages (from en-core-web-sm==3.5.0) (3.5.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./.local/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.13)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.21.5)
# Requirement already satisfied: pathy>=0.10.0 in ./.local/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.11.0)
# Requirement already satisfied: jinja2 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./.local/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./.local/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in ./.local/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.4.0)
# Requirement already satisfied: setuptools in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (61.2.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (21.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.27.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.64.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./.local/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./.local/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.10)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./.local/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./.local/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.15)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./.local/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.5.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in ./.local/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in ./.local/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.12)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./.local/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.13)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in ./.local/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.26)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.4)
# Requirement already satisfied: pathlib-abc==0.1.1 in ./.local/lib/python3.9/site-packages (from pathy>=0.10.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./.local/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./.local/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.1.5)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./.local/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.11)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import nltk
import spacy
import re
import string

# Download required NLTK data
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')

# Download and load spaCy model
nlp = spacy.load('en_core_web_sm')

print("Setup complete!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 import nltk
# ----> 2 import spacy
#       3 import re
#       4 import string
#
# ModuleNotFoundError: No module named 'spacy'

# %%
import sys
print(sys.executable)
# Out:
# /opt/conda/envs/anaconda-2022.05-py39/bin/python

# %%
import sys
# !{sys.executable} -m pip install spacy==3.5.0 --user
# Out:
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: spacy==3.5.0 in ./.local/lib/python3.9/site-packages (3.5.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (2.0.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (1.0.5)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (8.1.12)
# Requirement already satisfied: jinja2 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy==3.5.0) (2.11.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy==3.5.0) (21.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (2.5.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (6.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (3.0.13)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy==3.5.0) (4.64.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (1.10.26)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (0.7.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy==3.5.0) (2.27.1)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy==3.5.0) (1.21.5)
# Requirement already satisfied: pathy>=0.10.0 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (0.11.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (3.5.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (1.0.15)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (2.0.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./.local/lib/python3.9/site-packages (from spacy==3.5.0) (1.1.3)
# Requirement already satisfied: setuptools in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from spacy==3.5.0) (61.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from packaging>=20.0->spacy==3.5.0) (3.0.4)
# Requirement already satisfied: pathlib-abc==0.1.1 in ./.local/lib/python3.9/site-packages (from pathy>=0.10.0->spacy==3.5.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./.local/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy==3.5.0) (4.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.0) (1.26.9)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in ./.local/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy==3.5.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./.local/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy==3.5.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy==3.5.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from jinja2->spacy==3.5.0) (2.0.1)

# %%
import sys
# !conda install -c conda-forge spacy=3.5.0 --yes
# Out:
# CondaValueError: You have chosen a non-default solver backend (libmamba) but it was not recognized. Choose one of: classic

# %%
import spacy
print(spacy.__version__)
# Out:
# 3.5.0

# %%
import nltk
import spacy
import re
import string

# Download required NLTK data
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')

# Download and load spaCy model
nlp = spacy.load('en_core_web_sm')

print("Setup complete!")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/5698cdec-4f77-4db5-bd97-2a3ccc7a40b4/nltk_data..
# [nltk_data]     .
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/5698cdec-4f77-4db5-bd97-2a3ccc7a40b4/nltk_data..
# [nltk_data]     .
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/5698cdec-4f77-4db5-bd97-2a3ccc7a40b4/nltk_data..
# [nltk_data]     .
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/5698cdec-4f77-4db5-bd97-2a3ccc7a40b4/nltk_data..
# [nltk_data]     .
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/5698cdec-4f77-4db5-bd97-2a3ccc7a40b4/nltk_data..
# [nltk_data]     .
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/5698cdec-4f77-4db5-bd97-2a3ccc7a40b4/nltk_data..
# [nltk_data]     .
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# Setup complete!

# %%
# Simple tokenization using split()
text = "Natural Language Processing is fascinating!"

# Basic split on whitespace
tokens_basic = text.split()
print("Basic split():", tokens_basic)

# Problem: punctuation is attached to words!
print("Last token:", tokens_basic[-1])  # 'fascinating!' includes the !
# Out:
# Basic split(): ['Natural', 'Language', 'Processing', 'is', 'fascinating!']
# Last token: fascinating!

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

text = "Hello! How are you doing today? I'm learning NLP. It's really interesting."

# Word tokenization
word_tokens = word_tokenize(text)
print("Word tokens:", word_tokens)

# Sentence tokenization
sent_tokens = sent_tokenize(text)
print("\nSentence tokens:")
for i, sent in enumerate(sent_tokens):
    print(f"  {i+1}. {sent}")
# Out:
# Word tokens: ['Hello', '!', 'How', 'are', 'you', 'doing', 'today', '?', 'I', "'m", 'learning', 'NLP', '.', 'It', "'s", 'really', 'interesting', '.']
#
# Sentence tokens:
#   1. Hello!
#   2. How are you doing today?
#   3. I'm learning NLP.
#   4. It's really interesting.

# %%
# NLTK handles contractions and punctuation better
text = "I can't believe it's not butter! Don't you think so?"

print("Basic split:", text.split())
print("NLTK tokenize:", word_tokenize(text))
# Out:
# Basic split: ['I', "can't", 'believe', "it's", 'not', 'butter!', "Don't", 'you', 'think', 'so?']
# NLTK tokenize: ['I', 'ca', "n't", 'believe', 'it', "'s", 'not', 'butter', '!', 'Do', "n't", 'you', 'think', 'so', '?']

# %%
# TODO: Exercise 1.1
# Tokenize the following text into words using NLTK
# Count how many tokens are produced

text = "Dr. Smith's patients can't understand why they're feeling unwell. Is it the flu?"

tokens = word_tokenize(text)
num_tokens = len(tokens)

print("Tokens:", tokens)
print("Number of tokens:", num_tokens)

assert num_tokens == 18, f"Expected 18 tokens, got {num_tokens}"
# Out:
# Tokens: ['Dr.', 'Smith', "'s", 'patients', 'ca', "n't", 'understand', 'why', 'they', "'re", 'feeling', 'unwell', '.', 'Is', 'it', 'the', 'flu', '?']
# Number of tokens: 18

# %%
# spaCy tokenization
text = "Apple is looking at buying U.K. startup for $1 billion."

doc = nlp(text)

# Get tokens
tokens = [token.text for token in doc]
print("Tokens:", tokens)

# spaCy provides additional information
print("\nDetailed token info:")
for token in doc:
    print(f"  {token.text:12} | POS: {token.pos_:6} | Is Stop: {token.is_stop}")
# Out:
# Tokens: ['Apple', 'is', 'looking', 'at', 'buying', 'U.K.', 'startup', 'for', '$', '1', 'billion', '.']
#
# Detailed token info:
#   Apple        | POS: PROPN  | Is Stop: False
#   is           | POS: AUX    | Is Stop: True
#   looking      | POS: VERB   | Is Stop: False
#   at           | POS: ADP    | Is Stop: True
#   buying       | POS: VERB   | Is Stop: False
#   U.K.         | POS: PROPN  | Is Stop: False
#   startup      | POS: NOUN   | Is Stop: False
#   for          | POS: ADP    | Is Stop: True
#   $            | POS: SYM    | Is Stop: False
#   1            | POS: NUM    | Is Stop: False
#   billion      | POS: NUM    | Is Stop: False
#   .            | POS: PUNCT  | Is Stop: False

# %%
# TODO: Exercise 1.2
# Use spaCy to tokenize the text and extract only:
# 1. Tokens that are NOT punctuation
# 2. Tokens that are NOT spaces
# Hint: use token.is_punct and token.is_space

text = "The quick, brown fox jumps over the lazy dog! Isn't it amazing?"

doc = nlp(text)

clean_tokens = [token.text for token in doc if not token.is_punct and not token.is_space ]


print("Clean tokens:", clean_tokens)
assert len(clean_tokens) == 13, f"Expected 13 tokens, got {len(clean_tokens)}"
# Out:
# Clean tokens: ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog', 'Is', "n't", 'it', 'amazing']

# %%
from nltk.tokenize import RegexpTokenizer, TweetTokenizer

# RegexpTokenizer - tokenize using a custom pattern
# \w+ matches word characters only (removes punctuation)
regexp_tokenizer = RegexpTokenizer(r'\w+')

text = "Hello! How's it going? #NLP @user123"
print("Regexp tokens:", regexp_tokenizer.tokenize(text))

# TweetTokenizer - designed for social media text
tweet_tokenizer = TweetTokenizer()
print("Tweet tokens:", tweet_tokenizer.tokenize(text))
# Out:
# Regexp tokens: ['Hello', 'How', 's', 'it', 'going', 'NLP', 'user123']
# Tweet tokens: ['Hello', '!', "How's", 'it', 'going', '?', '#NLP', '@user123']

# %%
# TODO: Exercise 1.3
# Create a RegexpTokenizer that extracts only alphabetic words (no numbers, no punctuation)
# Pattern hint: [a-zA-Z]+ matches one or more letters

from nltk.tokenize import RegexpTokenizer

text = "I have 3 cats and 2 dogs! Their names are Max123 and Bella."

alpha_tokenizer = RegexpTokenizer(r'[a-zA-Z]+')
alpha_tokens = alpha_tokenizer.tokenize(text)

print("Alphabetic tokens:", alpha_tokens)
assert alpha_tokens == ['I', 'have', 'cats', 'and', 'dogs', 'Their', 'names', 'are', 'Max', 'and', 'Bella'], "Check your pattern!"
# Out:
# Alphabetic tokens: ['I', 'have', 'cats', 'and', 'dogs', 'Their', 'names', 'are', 'Max', 'and', 'Bella']

# %%
from nltk.stem import PorterStemmer, SnowballStemmer

# Porter Stemmer (most common)
porter = PorterStemmer()

words = ["running", "runs", "ran", "runner", "easily", "fairly"]

print("Porter Stemmer:")
for word in words:
    print(f"  {word:12} -> {porter.stem(word)}")
# Out:
# Porter Stemmer:
#   running      -> run
#   runs         -> run
#   ran          -> ran
#   runner       -> runner
#   easily       -> easili
#   fairly       -> fairli

# %%
# Snowball Stemmer (supports multiple languages)
snowball = SnowballStemmer('english')

print("Snowball Stemmer:")
for word in words:
    print(f"  {word:12} -> {snowball.stem(word)}")

# Available languages
print("\nAvailable languages:", SnowballStemmer.languages)
# Out:
# Snowball Stemmer:
#   running      -> run
#   runs         -> run
#   ran          -> ran
#   runner       -> runner
#   easily       -> easili
#   fairly       -> fair
#
# Available languages: ('arabic', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'hungarian', 'italian', 'norwegian', 'porter', 'portuguese', 'romanian', 'russian', 'spanish', 'swedish')

# %%
# Stemming limitations - can produce non-words
problem_words = ["studies", "studying", "university", "universe", "beautiful", "beauty"]

print("Stemming can produce non-words:")
for word in problem_words:
    print(f"  {word:12} -> {porter.stem(word)}")
# Out:
# Stemming can produce non-words:
#   studies      -> studi
#   studying     -> studi
#   university   -> univers
#   universe     -> univers
#   beautiful    -> beauti
#   beauty       -> beauti

# %%
# TODO: Exercise 2.1
# Apply Porter stemming to all words in the sentence
# Return the stemmed tokens as a list

sentence = "The cats are running and jumping over the sleeping dogs"

stemmer = PorterStemmer()

# Step 1: Tokenize
tokens = word_tokenize(sentence)

# Step 2: Apply stemming to each token
stemmed_tokens = [stemmer.stem(token) for token in tokens]

print("Original:", tokens)
print("Stemmed:", stemmed_tokens)

assert stemmed_tokens == ['the', 'cat', 'are', 'run', 'and', 'jump', 'over', 'the', 'sleep', 'dog'], "Check your stemming!"
# Out:
# Original: ['The', 'cats', 'are', 'running', 'and', 'jumping', 'over', 'the', 'sleeping', 'dogs']
# Stemmed: ['the', 'cat', 'are', 'run', 'and', 'jump', 'over', 'the', 'sleep', 'dog']

# %%
import nltk
nltk.download('omw-1.4')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/5698cdec-4f77-4db5-bd97-2a3ccc7a40b4/nltk_data..
# [nltk_data]     .
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/5698cdec-4f77-4db5-bd97-2a3ccc7a40b4/nltk_data..
# [nltk_data]     .
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

words = ["running", "runs", "ran", "better", "studies", "feet", "geese"]

print("Lemmatization (default - assumes nouns):")
for word in words:
    print(f"  {word:12} -> {lemmatizer.lemmatize(word)}")
# Out:
# Lemmatization (default - assumes nouns):
#   running      -> running
#   runs         -> run
#   ran          -> ran
#   better       -> better
#   studies      -> study
#   feet         -> foot
#   geese        -> goose

# %%
# Lemmatization works better with POS tags
# pos: 'n' = noun, 'v' = verb, 'a' = adjective, 'r' = adverb

print("Lemmatization with POS tags:")
print(f"  running (verb):     {lemmatizer.lemmatize('running', pos='v')}")
print(f"  running (noun):     {lemmatizer.lemmatize('running', pos='n')}")
print(f"  better (adjective): {lemmatizer.lemmatize('better', pos='a')}")
print(f"  studies (verb):     {lemmatizer.lemmatize('studies', pos='v')}")
print(f"  studies (noun):     {lemmatizer.lemmatize('studies', pos='n')}")
# Out:
# Lemmatization with POS tags:
#   running (verb):     run
#   running (noun):     running
#   better (adjective): good
#   studies (verb):     study
#   studies (noun):     study

# %%
# TODO: Exercise 2.2
# Lemmatize the following words using the correct POS tag
# Fill in the POS tag for each word

lemmatizer = WordNetLemmatizer()

# Format: (word, pos_tag)
words_with_pos = [
    ("flying", "v"),      # verb -> fly
    ("happily", "r"),   # adverb -> happily (adverbs don't change much)
    ("worse", "a"),     # adjective -> bad
    ("mice", "n"),      # noun -> mouse
    ("are", "v"),       # verb -> be
]

print("Lemmatization results:")
for word, pos in words_with_pos:
    lemma = lemmatizer.lemmatize(word, pos=pos)
    print(f"  {word:12} ({pos}) -> {lemma}")

# Verify your answers
expected = ['fly', 'happily', 'bad', 'mouse', 'be']
results = [lemmatizer.lemmatize(w, pos=p) for w, p in words_with_pos]
assert results == expected, f"Expected {expected}, got {results}"
# Out:
# Lemmatization results:
#   flying       (v) -> fly
#   happily      (r) -> happily
#   worse        (a) -> bad
#   mice         (n) -> mouse
#   are          (v) -> be

# %%
# spaCy automatically determines POS and lemmatizes correctly
text = "The children are playing with their toys. They were running and jumping happily."

doc = nlp(text)

print("spaCy lemmatization (automatic POS detection):")
for token in doc:
    if token.text != token.lemma_:  # Only show words that change
        print(f"  {token.text:12} ({token.pos_:5}) -> {token.lemma_}")
# Out:
# spaCy lemmatization (automatic POS detection):
#   The          (DET  ) -> the
#   children     (NOUN ) -> child
#   are          (AUX  ) -> be
#   playing      (VERB ) -> play
#   toys         (NOUN ) -> toy
#   They         (PRON ) -> they
#   were         (AUX  ) -> be
#   running      (VERB ) -> run
#   jumping      (VERB ) -> jump

# %%
# TODO: Exercise 2.3
# Use spaCy to extract the lemmas of all non-punctuation tokens
# Return as a list of lowercase lemmas

text = "The dogs were barking loudly at the cats who were climbing the trees."

doc = nlp(text)

lemmas = [token.lemma_.lower() for token in doc if not token.is_punct ] 
# YOUR CODE HERE (list comprehension: token.lemma_.lower() for non-punct tokens)

print("Lemmas:", lemmas)
assert lemmas == ['the', 'dog', 'be', 'bark', 'loudly', 'at', 'the', 'cat', 'who', 'be', 'climb', 'the', 'tree'], "Check your lemmatization!"
# Out:
# Lemmas: ['the', 'dog', 'be', 'bark', 'loudly', 'at', 'the', 'cat', 'who', 'be', 'climb', 'the', 'tree']

# %%
# Compare the two approaches
words = ["studies", "studying", "better", "feet", "ran", "easily", "fairly", "wolves"]

porter = PorterStemmer()
lemmatizer = WordNetLemmatizer()

print(f"{'Word':<12} {'Stemmed':<12} {'Lemmatized':<12}")
print("-" * 36)
for word in words:
    stemmed = porter.stem(word)
    # For comparison, we'll use noun as default
    lemmatized = lemmatizer.lemmatize(word)
    print(f"{word:<12} {stemmed:<12} {lemmatized:<12}")
# Out:
# Word         Stemmed      Lemmatized
# ------------------------------------
# studies      studi        study
# studying     studi        studying
# better       better       better
# feet         feet         foot
# ran          ran          ran
# easily       easili       easily
# fairly       fairli       fairly
# wolves       wolv         wolf

# %%
# Compare the two approaches
words = ["studies", "studying", "better", "feet", "ran", "easily", "fairly", "wolves"]

porter = PorterStemmer()
lemmatizer = WordNetLemmatizer()

print(f"{'Word':<12} {'Stemmed':<12} {'Lemmatized':<12}")
print("-" * 36)
for word in words:
    stemmed = porter.stem(word)
    # For comparison, we'll use noun as default
    lemmatized = lemmatizer.lemmatize(word)
    print(f"{word:<12} {stemmed:<12} {lemmatized:<12}")
# Out:
# Word         Stemmed      Lemmatized
# ------------------------------------
# studies      studi        study
# studying     studi        studying
# better       better       better
# feet         feet         foot
# ran          ran          ran
# easily       easili       easily
# fairly       fairli       fairly
# wolves       wolv         wolf

# %%
from nltk.corpus import stopwords

# Get English stop words
stop_words_nltk = set(stopwords.words('english'))

print(f"Number of NLTK stop words: {len(stop_words_nltk)}")
print(f"\nSample stop words: {list(stop_words_nltk)[:20]}")
# Out:
# Number of NLTK stop words: 198
#
# Sample stop words: ["you're", "it's", "wasn't", 'be', 'all', "shouldn't", "hadn't", 'y', 'while', 'above', 'will', 'under', 'been', 'didn', 'own', 'there', "he's", "she'll", "isn't", 'that']

# %%
# Remove stop words from text
text = "The quick brown fox jumps over the lazy dog in the park"
tokens = word_tokenize(text.lower())

# Filter out stop words
filtered_tokens = [token for token in tokens if token not in stop_words_nltk]

print("Original tokens:", tokens)
print("Without stop words:", filtered_tokens)
# Out:
# Original tokens: ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog', 'in', 'the', 'park']
# Without stop words: ['quick', 'brown', 'fox', 'jumps', 'lazy', 'dog', 'park']

# %%
# TODO: Exercise 3.1
# Remove stop words from the following text and return the remaining tokens
# Make sure to lowercase the text first!

text = "This is a sample sentence showing the removal of stop words from the text"

# Step 1: Lowercase and tokenize
tokens = word_tokenize(text.lower())

# Step 2: Remove stop words
stop_words = set(stopwords.words('english'))
filtered = [word for word in tokens if word not in stop_words and word.isalpha()]

print("Filtered tokens:", filtered)
assert filtered == ['sample', 'sentence', 'showing', 'removal', 'stop', 'words', 'text'], "Check your filtering!"
# Out:
# Filtered tokens: ['sample', 'sentence', 'showing', 'removal', 'stop', 'words', 'text']

# %%
import string

# Python's string.punctuation
print("Punctuation characters:", string.punctuation)

# Method 1: Using str.translate()
text = "Hello, World! How's it going? #NLP @user"
translator = str.maketrans('', '', string.punctuation)
clean_text = text.translate(translator)
print("\nUsing translate():", clean_text)
# Out:
# Punctuation characters: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# Using translate(): Hello World Hows it going NLP user

# %%
# Method 2: Using regex
import re

text = "Hello, World! How's it going? #NLP @user 123"

# Remove all non-alphanumeric characters (keep spaces)
clean_text = re.sub(r'[^a-zA-Z\s]', '', text)
print("Regex (letters only):", clean_text)

# Remove punctuation but keep numbers
clean_text2 = re.sub(r'[^\w\s]', '', text)
print("Regex (alphanumeric):", clean_text2)
# Out:
# Regex (letters only): Hello World Hows it going NLP user
# Regex (alphanumeric): Hello World Hows it going NLP user 123

# %%
# Method 3: Using spaCy token attributes
text = "Hello! This is @user's tweet about #NLP. Check https://example.com!"

doc = nlp(text)

# Filter tokens
clean_tokens = [
    token.text for token in doc 
    if not token.is_punct 
    and not token.is_space
    and not token.like_url
]

print("Clean tokens:", clean_tokens)
# Out:
# Clean tokens: ['Hello', 'This', 'is', '@user', "'s", 'tweet', 'about', 'NLP', 'Check']

# %%
# TODO: Exercise 3.2
# Clean the following text by:
# 1. Removing URLs
# 2. Removing mentions (@user)
# 3. Removing hashtags (#topic)
# 4. Removing punctuation
# 5. Converting to lowercase
# Use regex for this exercise

text = "Check out @OpenAI's new model! https://openai.com #AI #MachineLearning It's amazing!!!"

# YOUR CODE HERE
# Hint: Apply multiple re.sub() operations
clean = text
clean = re.sub(r'http\S+|www\S+', '', clean)
clean = re.sub(r'@\w+', '', clean)
clean = re.sub(r'#\w+', '', clean)
clean = re.sub(r'[^\w\s]', '', clean)
clean = clean.lower()
clean = re.sub(r'\s+', '', clean).strip()

print(f"Clean text: '{clean}'")
assert clean == "check out new model its amazing", f"Got: '{clean}'"
# Out:
# Clean text: 'checkoutsnewmodelitsamazing'
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [53], in <cell line: 23>()
#      20 clean = re.sub(r'\s+', '', clean).strip()
#      22 print(f"Clean text: '{clean}'")
# ---> 23 assert clean == "check out new model its amazing", f"Got: '{clean}'"
#
# AssertionError: Got: 'checkoutsnewmodelitsamazing'

# %%
# TODO: Exercise 3.2
# Clean the following text by:
# 1. Removing URLs
# 2. Removing mentions (@user)
# 3. Removing hashtags (#topic)
# 4. Removing punctuation
# 5. Converting to lowercase
# Use regex for this exercise

text = "Check out @OpenAI's new model! https://openai.com #AI #MachineLearning It's amazing!!!"

# YOUR CODE HERE
clean = text
clean = re.sub(r'http\S+|www\S+', '', clean)        # Remove URLs
clean = re.sub(r'@\w+', '', clean)                   # Remove mentions
clean = re.sub(r'#\w+', '', clean)                   # Remove hashtags
clean = re.sub(r'[^\w\s]', '', clean)                # Remove punctuation
clean = clean.lower()                                 # Lowercase
clean = re.sub(r'\s+', ' ', clean).strip()           # Remove extra whitespace

print(f"Clean text: '{clean}'")
assert clean == "check out new model its amazing", f"Got: '{clean}'"
# Out:
# Clean text: 'check out s new model its amazing'
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [54], in <cell line: 22>()
#      19 clean = re.sub(r'\s+', ' ', clean).strip()           # Remove extra whitespace
#      21 print(f"Clean text: '{clean}'")
# ---> 22 assert clean == "check out new model its amazing", f"Got: '{clean}'"
#
# AssertionError: Got: 'check out s new model its amazing'

# %%
clean = text
clean = re.sub(r'http\S+|www\S+', '', clean)        # Remove URLs
clean = re.sub(r'@\w+\'s|@\w+', '', clean)          # Remove mentions (including @user's)
clean = re.sub(r'#\w+', '', clean)                   # Remove hashtags
clean = re.sub(r'[^\w\s]', '', clean)                # Remove punctuation
clean = clean.lower()                                 # Lowercase
clean = re.sub(r'\s+', ' ', clean).strip()           # Remove extra whitespace

print(f"Clean text: '{clean}'")
assert clean == "check out new model its amazing", f"Got: '{clean}'"
# Out:
# Clean text: 'check out new model its amazing'

# %%
def preprocess_pipeline_example(text):
    """
    Example preprocessing pipeline.
    
    Steps:
    1. Lowercase
    2. Remove URLs
    3. Remove special characters
    4. Tokenize
    5. Remove stop words
    6. Lemmatize
    """
    # Step 1: Lowercase
    text = text.lower()
    
    # Step 2: Remove URLs
    text = re.sub(r'https?://\S+', '', text)
    
    # Step 3: Remove special characters (keep only letters and spaces)
    text = re.sub(r'[^a-z\s]', '', text)
    
    # Step 4: Tokenize with spaCy
    doc = nlp(text)
    
    # Step 5 & 6: Remove stop words and lemmatize
    tokens = [
        token.lemma_ 
        for token in doc 
        if not token.is_stop 
        and not token.is_punct 
        and not token.is_space
        and len(token.text) > 1  # Remove single characters
    ]
    
    return tokens

# Test the pipeline
sample_text = """
The quick brown foxes are jumping over the lazy dogs! 
Check out https://example.com for more information.
This is SO amazing!!! #NLP #Python @user123
"""

result = preprocess_pipeline_example(sample_text)
print("Preprocessed tokens:", result)
# Out:
# Preprocessed tokens: ['quick', 'brown', 'fox', 'jump', 'lazy', 'dog', 'check', 'information', 'amazing', 'nlp', 'python', 'user']

# %%
# TODO: Exercise 4.1 (FINAL CHALLENGE)
# Create a complete preprocessing pipeline function that:
# 1. Converts text to lowercase
# 2. Removes URLs (http/https)
# 3. Removes email addresses
# 4. Removes mentions (@user) and hashtags (#topic)
# 5. Removes numbers
# 6. Removes punctuation and special characters
# 7. Tokenizes the text
# 8. Removes stop words
# 9. Applies lemmatization
# 10. Removes tokens with less than 2 characters
#
# The function should return a list of cleaned tokens

def preprocess_text(text):
    """
    Complete text preprocessing pipeline.
    
    Args:
        text (str): Raw input text
        
    Returns:
        list: List of preprocessed tokens
    """
    # YOUR CODE HERE
    
    # Step 1: Lowercase
    text = text.lower()
    
    # Step 2: Remove URLs
    text = re.sub(r'[http?|https?://\S+', '', text]')
    # Step 3: Remove emails
    text = re.sub(r'@/w+', '', text)
    # Step 4: Remove mentions and hashtags
    text = re.sub(r'#/w+', '', text)
    # Step 5: Remove numbers
    text = re.sub(r'')
    # Step 6: Remove punctuation/special characters
    
    # Step 7: Tokenize (use spaCy)
    
    # Step 8 & 9: Remove stop words and lemmatize
    
    # Step 10: Remove short tokens
    
    pass  # Remove this line and return your tokens

# %%
def preprocess_text(text):
    """
    Complete text preprocessing pipeline.
    
    Args:
        text (str): Raw input text
        
    Returns:
        list: List of preprocessed tokens
    """
    # Step 1: Lowercase
    text = text.lower()
    
    # Step 2: Remove URLs
    text = re.sub(r'http\S+|www\S+', '', text)
    
    # Step 3: Remove emails
    text = re.sub(r'\S+@\S+', '', text)
    
    # Step 4: Remove mentions and hashtags
    text = re.sub(r'@\w+|#\w+', '', text)
    
    # Step 5: Remove numbers
    text = re.sub(r'\d+', '', text)
    
    # Step 6: Remove punctuation/special characters
    text = re.sub(r'[^\w\s]', '', text)
    
    # Step 7: Tokenize using spaCy
    doc = nlp(text)
    
    # Step 8 & 9: Remove stop words and lemmatize
    tokens = [token.lemma_ for token in doc 
              if not token.is_stop 
              and not token.is_punct 
              and not token.is_space]
    
    # Step 10: Remove short tokens (less than 2 characters)
    tokens = [token for token in tokens if len(token) >= 2]
    
    return tokens


# Test it
result = preprocess_text(sample_text)
print("Preprocessed tokens:", result)
# Out:
# Preprocessed tokens: ['quick', 'brown', 'fox', 'jump', 'lazy', 'dog', 'check', 'information', 'amazing']

# %%
# Test your pipeline with this text
test_text = """
🚀 BREAKING NEWS!!! The researchers at @MIT have published 5 new papers 
about Natural Language Processing! Check out https://mit.edu/nlp for details.
Contact them at research@mit.edu for collaborations. #NLP #AI #Research

The experiments were conducted using state-of-the-art transformers models.
They achieved 95.5% accuracy on the benchmark datasets!!!
"""

result = preprocess_text(test_text)
print("Preprocessed tokens:")
print(result)

# Verify some expected tokens are in the result
expected_tokens = ['researcher', 'publish', 'paper', 'natural', 'language', 'processing']
for token in expected_tokens:
    assert token in result, f"Expected '{token}' in result"

# Verify unwanted elements are NOT in result
unwanted = ['@mit', 'https', 'mit.edu', '#nlp', '95.5', '!!!', 'the', 'a', 'at']
for item in unwanted:
    assert item not in result, f"'{item}' should not be in result"

print("\n✅ All tests passed!")
# Out:
# Preprocessed tokens:
# ['break', 'news', 'researcher', 'publish', 'new', 'paper', 'natural', 'language', 'processing', 'check', 'detail', 'contact', 'collaboration', 'experiment', 'conduct', 'stateoftheart', 'transformer', 'model', 'achieve', 'accuracy', 'benchmark', 'dataset']
#
# ✅ All tests passed!

# %%
# TODO: Exercise 4.2
# Apply your preprocessing pipeline to a list of documents
# Return a list of lists (one list of tokens per document)

documents = [
    "Machine learning is transforming the tech industry! @Google #ML",
    "I love programming in Python. It's so easy to learn! https://python.org",
    "The cats are sleeping on the couch. They're so lazy!",
    "Contact support@company.com for any questions about our AI products."
]

# Apply your pipeline to each document
processed_docs =[preprocess_text(doc) for doc in documents] #(list comprehension)

print("Processed documents:")
for i, doc in enumerate(processed_docs):
    print(f"  Doc {i+1}: {doc}")
# Out:
# Processed documents:
#   Doc 1: ['machine', 'learning', 'transform', 'tech', 'industry']
#   Doc 2: ['love', 'programming', 'python', 'easy', 'learn']
#   Doc 3: ['cat', 'sleep', 'couch', 'lazy']
#   Doc 4: ['contact', 'question', 'ai', 'product']

# %%
# Clone your repo first (only once)
# !git clone https://github.com/mathwadde/NLP_COURSE_WORK_2026_IOW.git
# Out:
# Cloning into 'NLP_COURSE_WORK_2026_IOW'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 16 (delta 7), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (16/16), 18.00 KiB | 50.00 KiB/s, done.

# %%
import os
os.chdir('NLP_COURSE_WORK_2026_IOW')  # go into the repo folder

# !git config --global user.email "iloriolatunjiwaheed@email.com"
# !git config --global user.name "ILORI_Waheed"

# !git add .
# !git commit -m "Add NLP assignment"
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Username for 'https://github.com':
